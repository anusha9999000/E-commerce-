# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import os

# %%
os.chdir("/Users/user/Desktop/DATA SETS")

# %%
dataset2=pd.read_csv("E-commerce.csv")

# %%
dataset2.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0     835 Frank Tunnel\r\nWrightmouth, MI 82180-9605            Violet
# 1   4547 Archer Common\r\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\r\nCobbborough,...            Bisque
# 3  1414 David Throughway\r\nPort Jason, OH 22070-...       SaddleBrown
# 4  14023 Rodriguez Passage\r\nPort Jacobville, PR...  MediumAquaMarine
#
#    Avg_session   Time_app  Time_website  Membership  Total_amount_spent
# 0    34.497268  12.655651     39.577668    4.082621          587.951054
# 1    31.926272  11.109461     37.268959    2.664034          392.204933
# 2    33.000915  11.330278     37.110597    4.104543          487.547505
# ...

# %%
dataset2.drop(["Email","Address","Avatar","Time_app"],axis=1,inplace=True)

# %%
dataset2
# Out:
#      Avg_session  Time_website  Membership  Total_amount_spent
# 0      34.497268     39.577668    4.082621          587.951054
# 1      31.926272     37.268959    2.664034          392.204933
# 2      33.000915     37.110597    4.104543          487.547505
# 3      34.305557     36.721283    3.120179          581.852344
# 4      33.330673     37.536653    4.446308          599.406092
# 5      33.871038     34.476878    5.493507          637.102448
# 6      32.021596     36.683776    4.685017          521.572175
# 7      32.739143     37.373359    4.434273          549.904146
# 8      33.987773     37.534497    3.273434          570.200409
# 9      31.936549     37.145168    3.202806          427.199385
# 10     33.992573     37.225806    2.482608          492.606013
# 11     33.879361     37.087926    3.713209          522.337405
# 12     29.532429     37.420216    4.046423          408.640351
# 13     33.190334     36.144667    3.918542          573.415867
# ...

# %%
x=dataset2.iloc[:,0:3]
x
# Out:
#      Avg_session  Time_website  Membership
# 0      34.497268     39.577668    4.082621
# 1      31.926272     37.268959    2.664034
# 2      33.000915     37.110597    4.104543
# 3      34.305557     36.721283    3.120179
# 4      33.330673     37.536653    4.446308
# 5      33.871038     34.476878    5.493507
# 6      32.021596     36.683776    4.685017
# 7      32.739143     37.373359    4.434273
# 8      33.987773     37.534497    3.273434
# 9      31.936549     37.145168    3.202806
# 10     33.992573     37.225806    2.482608
# 11     33.879361     37.087926    3.713209
# 12     29.532429     37.420216    4.046423
# 13     33.190334     36.144667    3.918542
# 14     32.387976     36.619957    2.494544
# 15     30.737720     36.213763    3.357847
# 16     32.125387     34.894093    3.136133
# 17     32.338899     38.385137    2.420806
# 18     32.187812     38.244115    1.516576
# 19     32.617856     37.190504    4.064549
# 20     32.912785     37.607793    4.599937
# ...

# %%
y=dataset2.iloc[:,3]
y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
# 5      637.102448
# 6      521.572175
# 7      549.904146
# 8      570.200409
# 9      427.199385
# 10     492.606013
# 11     522.337405
# 12     408.640351
# 13     573.415867
# 14     470.452733
# 15     461.780742
# 16     457.847696
# 17     407.704547
# 18     452.315675
# 19     605.061039
# 20     534.705744
# 21     419.938775
# 22     436.515606
# 23     519.340989
# 24     700.917092
# 25     423.179992
# 26     619.895640
# 27     486.838935
# 28     529.537665
# 29     554.722084
#           ...
# 470    424.728774
# 471    541.049831
# 472    469.383146
# 473    444.545550
# 474    492.556834
# 475    535.321610
# 476    408.958336
# 477    487.555458
# 478    487.646232
# 479    402.167122
# 480    551.023002
# 481    497.389558
# 482    494.638610
# 483    479.247417
# 484    462.656519
# 485    515.502480
# 486    576.477607
# 487    357.857984
# 488    597.739879
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#      Avg_session  Time_website  Membership
# 107    32.063775     37.712509    3.004743
# 336    32.302553     38.269061    3.532862
# 71     34.335896     36.157191    4.694322
# 474    33.700886     37.071643    2.379076
# 6      32.021596     36.683776    4.685017
# 412    33.863189     35.938045    3.013033
# 113    32.653181     37.309689    2.789462
# 236    32.693240     37.370118    3.467014
# 299    30.492537     35.976565    1.481617
# 155    32.449522     37.238806    2.941411
# 272    34.436426     36.768603    3.371258
# 7      32.739143     37.373359    4.434273
# 137    34.558295     36.494406    2.491672
# 8      33.987773     37.534497    3.273434
# 463    31.874552     36.929762    3.491093
# 432    31.123974     35.632112    4.288487
# 375    33.582947     36.908190    2.479340
# 284    31.312350     38.717076    3.594295
# 210    31.765619     38.131712    3.850280
# 188    32.283123     36.094242    4.789202
# 430    33.749228     38.401374    4.595523
# ...

# %%
y_train
# Out:
# 107    378.330907
# 336    478.600916
# 71     595.822837
# 474    492.556834
# 6      521.572175
# 412    444.053827
# 113    422.426776
# 236    501.928265
# 299    282.471246
# 155    503.978379
# 272    582.491924
# 7      549.904146
# 137    433.048769
# 8      570.200409
# 463    392.285244
# 432    486.947054
# 375    478.951405
# 284    463.591418
# 210    496.554082
# 188    524.637965
# 430    556.186369
# 49     416.358354
# 134    407.804031
# 365    594.274483
# 413    493.181261
# 239    538.774933
# 59     547.365141
# 406    411.186964
# 391    503.175085
# 411    589.026490
#           ...
# 265    567.475011
# 72     418.150081
# 333    498.635599
# 25     423.179992
# 165    513.450571
# 337    440.002747
# 483    479.247417
# 174    465.176623
# 486    576.477607
# 39     537.846195
# 193    545.945492
# 314    610.128033
# 396    669.987141
# 88     547.125932
# 472    469.383146
# 70     444.966552
# 87     473.728967
# 292    584.218314
# 242    451.628611
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=mlr.predict(x_test)

# %%
y_pred
# Out:
# array([421.23178592, 478.24687482, 386.06121814, 525.6285801 ,
#        518.77668367, 430.75423549, 448.33700678, 364.40252063,
#        554.62739171, 634.0990386 , 536.04099411, 519.04564768,
#        557.38813264, 425.92245213, 396.11261532, 382.05921431,
#        538.16835079, 445.20679262, 592.69312746, 489.49235482,
#        644.32251275, 504.56855704, 428.19576553, 525.27314197,
#        549.10141374, 478.2524513 , 385.59046194, 453.72015734,
#        554.36783895, 492.33315496, 483.90393218, 509.11131206,
#        518.84771761, 477.08026482, 508.94230359, 432.21840159,
#        500.55845933, 447.67063205, 571.45495303, 376.17946264,
#        536.43689057, 557.42213282, 580.92436973, 624.00042979,
#        465.5152266 , 417.97651749, 485.73043911, 417.95610061,
#        495.10670704, 425.81789898, 495.63665664, 471.03001445,
#        552.80414319, 483.80892857, 462.64179419, 449.67410724,
#        524.02295188, 313.01119095, 568.4524311 , 499.97173704,
# ...

# %%
y_test
# Out:
# 90     449.070319
# 254    482.602467
# 283    374.269675
# 445    513.153112
# 461    502.771075
# 15     461.780742
# 316    466.421199
# 489    327.377953
# 159    528.223809
# 153    657.019924
# 241    571.471034
# 250    523.633935
# 390    546.556667
# 289    467.427849
# 171    439.891280
# 329    445.062186
# 468    553.994674
# 355    403.766902
# 154    595.803819
# 37     490.738632
# 205    712.396327
# 366    502.092528
# 240    398.163469
# 108    570.451726
# 45     549.860591
# 438    392.992256
# 21     419.938775
# 367    407.657179
# 96     521.142952
# 233    463.745981
#           ...
# 142    463.923513
# 65     765.518462
# 340    501.122492
# 484    462.656519
# 175    373.885724
# 362    384.326057
# 264    614.729638
# 100    518.064558
# 491    510.501479
# 295    432.720718
# 300    473.949857
# 235    501.209173
# 475    535.321610
# 219    496.933446
# 330    442.064414
# 326    505.230068
# 421    544.409272
# 157    744.221867
# 348    392.810345
# ...

# %%
mlr.score(x_train, y_train)
# Out:
# 0.7474170554739776

# %%
mlr.intercept_
# Out:
# -617.8154353770924

# %%
mlr.coef_
# Out:
# array([23.60159858,  3.03741998, 63.46743478])

# %%
x_train.shape
# Out:
# (400, 3)

# %%
pre=mlr.predict([[300,3289,5.0]])

# %%
pre
# Out:
# array([16770.07562146])

# %%
dataset2.corr()
# Out:
#                     Avg_session  Time_website  Membership  Total_amount_spent
# Avg_session            1.000000     -0.034987    0.060247            0.355088
# Time_website          -0.034987      1.000000   -0.047582           -0.002641
# Membership             0.060247     -0.047582    1.000000            0.809084
# Total_amount_spent     0.355088     -0.002641    0.809084            1.000000

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7598148033285872

# %%
mlr.score(x_train,y_train)
# Out:
# 0.7474170554739776

# %%
mlr.score(x_test,y_test)
# Out:
# 0.7598148033285872

# %%
dataset2.boxplot(column='Time_website',by='Total_amount_spent')

# %%
import seaborn as sns

# %%
x=dataset2['Time_website']
y=dataset2['Total_amount_spent']

# %%
bx=plt.plot(x,y,'o')
plt.xlabel("Time_website")
plt.ylabel("Total_amount_spent")
# Out:
# Text(0, 0.5, 'Total_amount_spent')

# %%
sns.distplot(dataset2['Time_website'])

# %%
# Plot the correlation usinf heatmap
corr = dataset2.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
mean_x=dataset2['Time_website'].mean()

# %%
#Plot a regression line
plt.plot(x,y,'o')
plt.ylabel("Total amount spent")
plt.xlabel("Time_website")
plt.axhline(mean_x, color='r', linestyle='-')
#regression plot
sns.regplot(x='Time_website', y='Total_amount_spent', data=dataset2)

# %%
#Visualize the predictions
plt.scatter(y_test,y_pred)
