# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import os

# %%
os.chdir("/Users/user/Desktop/DATA SETS")

# %%
dataset1=pd.read_csv("E-commerce.csv")

# %%
dataset1.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0     835 Frank Tunnel\r\nWrightmouth, MI 82180-9605            Violet
# 1   4547 Archer Common\r\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\r\nCobbborough,...            Bisque
# 3  1414 David Throughway\r\nPort Jason, OH 22070-...       SaddleBrown
# 4  14023 Rodriguez Passage\r\nPort Jacobville, PR...  MediumAquaMarine
#
#    Avg_session   Time_app  Time_website  Membership  Total_amount_spent
# 0    34.497268  12.655651     39.577668    4.082621          587.951054
# 1    31.926272  11.109461     37.268959    2.664034          392.204933
# 2    33.000915  11.330278     37.110597    4.104543          487.547505
# ...

# %%
dataset1.drop(["Email","Address","Avatar","Time_website"],axis=1,inplace=True)

# %%
dataset1
# Out:
#      Avg_session   Time_app  Membership  Total_amount_spent
# 0      34.497268  12.655651    4.082621          587.951054
# 1      31.926272  11.109461    2.664034          392.204933
# 2      33.000915  11.330278    4.104543          487.547505
# 3      34.305557  13.717514    3.120179          581.852344
# 4      33.330673  12.795189    4.446308          599.406092
# 5      33.871038  12.026925    5.493507          637.102448
# 6      32.021596  11.366348    4.685017          521.572175
# 7      32.739143  12.351959    4.434273          549.904146
# 8      33.987773  13.386235    3.273434          570.200409
# 9      31.936549  11.814128    3.202806          427.199385
# 10     33.992573  13.338975    2.482608          492.606013
# 11     33.879361  11.584783    3.713209          522.337405
# 12     29.532429  10.961298    4.046423          408.640351
# 13     33.190334  12.959226    3.918542          573.415867
# 14     32.387976  13.148726    2.494544          470.452733
# ...

# %%
x=dataset1.iloc[:,0:3]
x
# Out:
#      Avg_session   Time_app  Membership
# 0      34.497268  12.655651    4.082621
# 1      31.926272  11.109461    2.664034
# 2      33.000915  11.330278    4.104543
# 3      34.305557  13.717514    3.120179
# 4      33.330673  12.795189    4.446308
# 5      33.871038  12.026925    5.493507
# 6      32.021596  11.366348    4.685017
# 7      32.739143  12.351959    4.434273
# 8      33.987773  13.386235    3.273434
# 9      31.936549  11.814128    3.202806
# 10     33.992573  13.338975    2.482608
# 11     33.879361  11.584783    3.713209
# 12     29.532429  10.961298    4.046423
# 13     33.190334  12.959226    3.918542
# 14     32.387976  13.148726    2.494544
# 15     30.737720  12.636606    3.357847
# 16     32.125387  11.733862    3.136133
# 17     32.338899  12.013195    2.420806
# 18     32.187812  14.715388    1.516576
# 19     32.617856  13.989593    4.064549
# 20     32.912785  11.365492    4.599937
# 21     33.503087  12.877984    1.559152
# ...

# %%
y=dataset1.iloc[:,3]
y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
# 5      637.102448
# 6      521.572175
# 7      549.904146
# 8      570.200409
# 9      427.199385
# 10     492.606013
# 11     522.337405
# 12     408.640351
# 13     573.415867
# 14     470.452733
# 15     461.780742
# 16     457.847696
# 17     407.704547
# 18     452.315675
# 19     605.061039
# 20     534.705744
# 21     419.938775
# 22     436.515606
# 23     519.340989
# 24     700.917092
# 25     423.179992
# 26     619.895640
# 27     486.838935
# 28     529.537665
# 29     554.722084
#           ...
# 470    424.728774
# 471    541.049831
# 472    469.383146
# 473    444.545550
# 474    492.556834
# 475    535.321610
# 476    408.958336
# 477    487.555458
# 478    487.646232
# 479    402.167122
# 480    551.023002
# 481    497.389558
# 482    494.638610
# 483    479.247417
# 484    462.656519
# 485    515.502480
# 486    576.477607
# 487    357.857984
# 488    597.739879
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#      Avg_session   Time_app  Membership
# 107    32.063775  10.719150    3.004743
# 336    32.302553  11.979061    3.532862
# 71     34.335896  12.228935    4.694322
# 474    33.700886  13.471578    2.379076
# 6      32.021596  11.366348    4.685017
# 412    33.863189  11.523523    3.013033
# 113    32.653181  11.602532    2.789462
# 236    32.693240  12.600750    3.467014
# 299    30.492537  11.562936    1.481617
# 155    32.449522  13.457725    2.941411
# 272    34.436426  13.325469    3.371258
# 7      32.739143  12.351959    4.434273
# 137    34.558295  11.281445    2.491672
# 8      33.987773  13.386235    3.273434
# 463    31.874552  10.290351    3.491093
# 432    31.123974  12.386516    4.288487
# 375    33.582947  12.761531    2.479340
# 284    31.312350  11.684904    3.594295
# 210    31.765619  12.442617    3.850280
# 188    32.283123  10.902556    4.789202
# 430    33.749228  11.137140    4.595523
# 49     31.661050  11.398064    3.198399
# ...

# %%
y_train
# Out:
# 107    378.330907
# 336    478.600916
# 71     595.822837
# 474    492.556834
# 6      521.572175
# 412    444.053827
# 113    422.426776
# 236    501.928265
# 299    282.471246
# 155    503.978379
# 272    582.491924
# 7      549.904146
# 137    433.048769
# 8      570.200409
# 463    392.285244
# 432    486.947054
# 375    478.951405
# 284    463.591418
# 210    496.554082
# 188    524.637965
# 430    556.186369
# 49     416.358354
# 134    407.804031
# 365    594.274483
# 413    493.181261
# 239    538.774933
# 59     547.365141
# 406    411.186964
# 391    503.175085
# 411    589.026490
#           ...
# 265    567.475011
# 72     418.150081
# 333    498.635599
# 25     423.179992
# 165    513.450571
# 337    440.002747
# 483    479.247417
# 174    465.176623
# 486    576.477607
# 39     537.846195
# 193    545.945492
# 314    610.128033
# 396    669.987141
# 88     547.125932
# 472    469.383146
# 70     444.966552
# 87     473.728967
# 292    584.218314
# 242    451.628611
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=mlr.predict(x_test)

# %%
y_pred
# Out:
# array([438.1404823 , 489.87345951, 370.73952854, 514.53747494,
#        496.52832824, 451.38517892, 457.92666147, 336.67120131,
#        527.86406659, 663.34672426, 559.8992604 , 525.97960453,
#        552.20324819, 456.99735768, 450.35224933, 432.26932691,
#        563.37396364, 408.84417536, 599.57357291, 486.86762303,
#        716.21840232, 496.89302863, 411.58372426, 556.05798634,
#        550.83428089, 398.09394766, 421.18533872, 395.64871293,
#        548.0268624 , 463.37074562, 558.56219397, 504.9607563 ,
#        505.62827758, 463.91251754, 425.49868544, 400.6920785 ,
#        503.80876344, 430.42712747, 570.14832277, 422.06126131,
#        487.64450417, 602.23615524, 615.87419374, 589.03631903,
#        449.92546554, 379.8534969 , 558.81444112, 463.11734659,
#        502.21160311, 401.21309776, 524.60465018, 416.51958578,
#        576.48396126, 477.92036018, 457.06180323, 397.57331228,
#        564.8017637 , 305.25062317, 562.26673115, 476.93939025,
# ...

# %%
y_test
# Out:
# 90     449.070319
# 254    482.602467
# 283    374.269675
# 445    513.153112
# 461    502.771075
# 15     461.780742
# 316    466.421199
# 489    327.377953
# 159    528.223809
# 153    657.019924
# 241    571.471034
# 250    523.633935
# 390    546.556667
# 289    467.427849
# 171    439.891280
# 329    445.062186
# 468    553.994674
# 355    403.766902
# 154    595.803819
# 37     490.738632
# 205    712.396327
# 366    502.092528
# 240    398.163469
# 108    570.451726
# 45     549.860591
# 438    392.992256
# 21     419.938775
# 367    407.657179
# 96     521.142952
# 233    463.745981
#           ...
# 142    463.923513
# 65     765.518462
# 340    501.122492
# 484    462.656519
# 175    373.885724
# 362    384.326057
# 264    614.729638
# 100    518.064558
# 491    510.501479
# 295    432.720718
# 300    473.949857
# 235    501.209173
# 475    535.321610
# 219    496.933446
# 330    442.064414
# 326    505.230068
# 421    544.409272
# 157    744.221867
# 348    392.810345
# ...

# %%
mlr.score(x_train,y_train)
# Out:
# 0.9837009889102284

# %%
mlr.score(x_test,y_test)
# Out:
# 0.9861886859803264

# %%
mlr.coef_
# Out:
# array([25.85796569, 38.90369968, 61.76538658])

# %%
x_train.shape
# Out:
# (400, 3)

# %%
pre=mlr.predict([[300,3289,5.0]])

# %%
pre
# Out:
# array([134978.04572799])

# %%
dataset1.corr()
# Out:
#                     Avg_session  Time_app  Membership  Total_amount_spent
# Avg_session            1.000000 -0.027826    0.060247            0.355088
# Time_app              -0.027826  1.000000    0.029143            0.499328
# Membership             0.060247  0.029143    1.000000            0.809084
# Total_amount_spent     0.355088  0.499328    0.809084            1.000000

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9861886859803263

# %%
mlr.score(x_train,y_train)
# Out:
# 0.9837009889102284

# %%
mlr.score(x_test,y_test)
# Out:
# 0.9861886859803264

# %%
import seaborn as sns

# %%
x=dataset1['Time_app']
y=dataset1['Total_amount_spent']

# %%
bx=plt.plot(x,y,'o')
plt.xlabel("Time_app")
plt.ylabel("Total_amount_spent")
# Out:
# Text(0, 0.5, 'Total_amount_spent')

# %%
sns.distplot(dataset1['Time_app'])

# %%
# Plot the correlation usinf heatmap
corr = dataset1.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
mean_x=dataset1['Time_app'].mean()

# %%
#Plot a regression line
plt.plot(x,y,'o')
plt.ylabel("Total amount spent")
plt.xlabel("Time_app")
plt.axhline(mean_x, color='r', linestyle='-')
#regression plot
sns.regplot(x='Time_app', y='Total_amount_spent', data=dataset1)

# %%
#Visualize the predictions
plt.scatter(y_test,y_pred)
